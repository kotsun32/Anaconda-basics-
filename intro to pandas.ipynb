# %%
import pandas as pd

# %%
#2 main data types:
series = pd.Series(["BMW","Honda","Toyota"])

# %%
series
# Out:
# 0       BMW
# 1     Honda
# 2    Toyota
# dtype: object

# %%
#series = 1 demensional

# %%
colors = pd.Series(["White","Red","Blue"])
colors
# Out:
# 0    White
# 1      Red
# 2     Blue
# dtype: object

# %%
#Dataframe 2 demensional:
car_data = pd.DataFrame({"Car make":series, "Color": colors})

# %%
car_data
# Out:
#   Car make  Color
# 0      BMW  White
# 1    Honda    Red
# 2   Toyota   Blue

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# axis = 0 == row, axis = 1 == column

# %%
#exporting 
car_sales.to_csv("exported_car_sales.csv",index = False)

# %%
 exported_car_sales = pd.read_csv("exported_car_sales.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#dtypes basically what types each column is.
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
#storing colums as list
car_columns = car_sales.columns

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#describe works on numbers only*
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# /var/folders/5z/3yrmkztd53d2q3tfg21lyc1r0000gn/T/ipykernel_46583/4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000,5000,4500])
car_prices.mean()
# Out:
# 4166.666666666667

# %%
#for non num just combines the strings
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Make"] == "Toyota"][car_sales["Doors"]==4]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Make"] == "Toyota"][car_sales["Doors"]==4]
# Out:
# /var/folders/5z/3yrmkztd53d2q3tfg21lyc1r0000gn/T/ipykernel_46583/3120032546.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   car_sales[car_sales["Make"] == "Toyota"][car_sales["Doors"]==4]
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
#loc == index
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#iloc == position
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
#make sure plots show up
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Doors"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]','').astype(float)
# Out:
# /var/folders/5z/3yrmkztd53d2q3tfg21lyc1r0000gn/T/ipykernel_46583/4176985008.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]','').astype(float)

# %%
car_sales["Price"].mean()
# Out:
# 7645.0

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# to change column permenent need to set =:
car_sales["Make"]=car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace =True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_dropped = car_sales_missing.dropna(inplace =True)

# %%
car_sales_missing_dropped

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#colum from a series 
seat_colum = pd.Series([5,6,7,8,9])

# %%
seat_colum
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# 4    9
# dtype: int64

# %%
#new colum in data
car_sales["Seats"] = seat_colum

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    6.0
# 2  toyota   Blue          32549      3   7000.0    7.0
# 3     bmw  Black          11179      5  22000.0    8.0
# 4  nissan  White         213095      4   3500.0    9.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5,inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    6.0
# 2  toyota   Blue          32549      3   7000.0    7.0
# 3     bmw  Black          11179      5  22000.0    8.0
# 4  nissan  White         213095      4   3500.0    9.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
#add array needs to be same length as list/ Series does not!
fuel_econ = [7.5,6.0,5.5,4.5,5.0,6.0,7.0,9.3,8.9,10.1]
car_sales["Fuel per 100k"] = fuel_econ

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    6.0            6.0
# 2  toyota   Blue          32549      3   7000.0    7.0            5.5
# 3     bmw  Black          11179      5  22000.0    8.0            4.5
# 4  nissan  White         213095      4   3500.0    9.0            5.0
# 5  toyota  Green          99213      4   4500.0    5.0            6.0
# 6   honda   Blue          45698      4   7500.0    5.0            7.0
# 7   honda   Blue          54738      4   7000.0    5.0            9.3
# 8  toyota  White          60000      4   6250.0    5.0            8.9
# 9  nissan  White          31600      4   9700.0    5.0           10.1

# %%
car_sales["Number of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k  \
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    6.0            6.0
# 2  toyota   Blue          32549      3   7000.0    7.0            5.5
# 3     bmw  Black          11179      5  22000.0    8.0            4.5
# 4  nissan  White         213095      4   3500.0    9.0            5.0
# 5  toyota  Green          99213      4   4500.0    5.0            6.0
# 6   honda   Blue          45698      4   7500.0    5.0            7.0
# 7   honda   Blue          54738      4   7000.0    5.0            9.3
# 8  toyota  White          60000      4   6250.0    5.0            8.9
# 9  nissan  White          31600      4   9700.0    5.0           10.1
#
#    Number of Wheels
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# 5                 4
# 6                 4
# 7                 4
# ...

# %%
car_sales.drop("Number of Wheels",axis = 1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    6.0            6.0
# 2  toyota   Blue          32549      3   7000.0    7.0            5.5
# 3     bmw  Black          11179      5  22000.0    8.0            4.5
# 4  nissan  White         213095      4   3500.0    9.0            5.0
# 5  toyota  Green          99213      4   4500.0    5.0            6.0
# 6   honda   Blue          45698      4   7500.0    5.0            7.0
# 7   honda   Blue          54738      4   7000.0    5.0            9.3
# 8  toyota  White          60000      4   6250.0    5.0            8.9
# 9  nissan  White          31600      4   9700.0    5.0           10.1

# %%
car_sales =car_sales.drop("Number of Wheels",axis = 1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    6.0            6.0
# 2  toyota   Blue          32549      3   7000.0    7.0            5.5
# 3     bmw  Black          11179      5  22000.0    8.0            4.5
# 4  nissan  White         213095      4   3500.0    9.0            5.0
# 5  toyota  Green          99213      4   4500.0    5.0            6.0
# 6   honda   Blue          45698      4   7500.0    5.0            7.0
# 7   honda   Blue          54738      4   7000.0    5.0            9.3
# 8  toyota  White          60000      4   6250.0    5.0            8.9
# 9  nissan  White          31600      4   9700.0    5.0           10.1

# %%
car_sales_shuffled= car_sales.sample(frac=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k
# 0  toyota  White         150043      4   4000.0    5.0            7.5
# 1   honda    Red          87899      4   5000.0    6.0            6.0
# 2  toyota   Blue          32549      3   7000.0    7.0            5.5
# 3     bmw  Black          11179      5  22000.0    8.0            4.5
# 4  nissan  White         213095      4   3500.0    9.0            5.0
# 5  toyota  Green          99213      4   4500.0    5.0            6.0
# 6   honda   Blue          45698      4   7500.0    5.0            7.0
# 7   honda   Blue          54738      4   7000.0    5.0            9.3
# 8  toyota  White          60000      4   6250.0    5.0            8.9
# 9  nissan  White          31600      4   9700.0    5.0           10.1

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k
# 3     bmw  Black          11179      5  22000.0    8.0            4.5
# 1   honda    Red          87899      4   5000.0    6.0            6.0
# 8  toyota  White          60000      4   6250.0    5.0            8.9
# 4  nissan  White         213095      4   3500.0    9.0            5.0
# 7   honda   Blue          54738      4   7000.0    5.0            9.3
# 6   honda   Blue          45698      4   7500.0    5.0            7.0
# 2  toyota   Blue          32549      3   7000.0    7.0            5.5
# 5  toyota  Green          99213      4   4500.0    5.0            6.0
# 9  nissan  White          31600      4   9700.0    5.0           10.1
# 0  toyota  White         150043      4   4000.0    5.0            7.5

# %%
#take less data in this case 20%
car_sales_shuffled.sample(frac=.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100k
# 1   honda    Red          87899      4  5000.0    6.0            6.0
# 4  nissan  White         213095      4  3500.0    9.0            5.0

# %%
car_sales_shuffled.reset_index(drop=True,inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k
# 0     bmw  Black          11179      5  22000.0    8.0            4.5
# 1   honda    Red          87899      4   5000.0    6.0            6.0
# 2  toyota  White          60000      4   6250.0    5.0            8.9
# 3  nissan  White         213095      4   3500.0    9.0            5.0
# 4   honda   Blue          54738      4   7000.0    5.0            9.3
# 5   honda   Blue          45698      4   7500.0    5.0            7.0
# 6  toyota   Blue          32549      3   7000.0    7.0            5.5
# 7  toyota  Green          99213      4   4500.0    5.0            6.0
# 8  nissan  White          31600      4   9700.0    5.0           10.1
# 9  toyota  White         150043      4   4000.0    5.0            7.5

# %%
car_sales["Odometer (KM)"]/1.6
# Out:
# 0     93776.875
# 1     54936.875
# 2     20343.125
# 3      6986.875
# 4    133184.375
# 5     62008.125
# 6     28561.250
# 7     34211.250
# 8     37500.000
# 9     19750.000
# Name: Odometer (KM), dtype: float64

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100k
# 0  toyota  White      93776.875      4   4000.0    5.0            7.5
# 1   honda    Red      54936.875      4   5000.0    6.0            6.0
# 2  toyota   Blue      20343.125      3   7000.0    7.0            5.5
# 3     bmw  Black       6986.875      5  22000.0    8.0            4.5
# 4  nissan  White     133184.375      4   3500.0    9.0            5.0
# 5  toyota  Green      62008.125      4   4500.0    5.0            6.0
# 6   honda   Blue      28561.250      4   7500.0    5.0            7.0
# 7   honda   Blue      34211.250      4   7000.0    5.0            9.3
# 8  toyota  White      37500.000      4   6250.0    5.0            8.9
# 9  nissan  White      19750.000      4   9700.0    5.0           10.1
