# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
x = [1,2,3,4]
y= [11,22,44,33]
plt.plot(x,y)

# %%
fig = plt.figure() #create figure 
ax = fig.add_subplot() # addes axes 
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y);

# %%
x = [1,2,3,4,5]
y=[2,4,6,8,10]
fig, ax =plt.subplots(figsize=(10,10)) #setting demensions 

ax.plot(x,y) #plotting 
ax.set(title= "Simple plt",xlabel = "x-axis",ylabel="y-axis")

fig.savefig("fig_1.png")

# %% [markdown]
# ##Making figures with numpy arrays

# %%
import numpy as np

# %%
x= np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, ax = plt.subplots()
ax.plot(x,x**2); # plot needs 2 points

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.exp(x)) # scatter plot

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
nut_butter_prices = {"Almond":12,
                       "peanuts":10,
                       "cashews":14}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title = "Butter Prices",ylabel = "Price ($)",xlabel = "Nutz");

# %%
nut_butter_prices = {"Almond":12,
                       "peanuts":10,
                       "cashews":14}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title = "Butter Prices",ylabel = "Price ($)",xlabel = "Nutz") #without semicoln at end we get this odd text array
# last line where ax is referenced!
# Out:
# [Text(0.5, 1.0, 'Butter Prices'),
#  Text(0, 0.5, 'Price ($)'),
#  Text(0.5, 0, 'Nutz')]

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values())) # histogram needs list
# Out:
# <BarContainer object of 3 artists>

# %%
x = np.random.randn(1000) # normal dist over 1000 values 
fig, ax =plt.subplots()
ax.hist(x);

# %%
fig, ((ax1,ax2),(ax3,ax4)) =plt.subplots(nrows =2,
                                         ncols = 2,
                                          figsize = (10,5))
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.plot(x/2,x/2);
#plt.subplots allow for this dynamics showing of multiple types of graphs

# %%
fig, ((ax1,ax2),(ax3,ax4),(ax5,ax6)) =plt.subplots(nrows =3,
                                         ncols = 2,
                                          figsize = (10,10))

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index = pd.date_range("1/1/2020",periods = 1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales["Price"] = car_sales["Price"].str.replace('[\$,\.\,]','')
car_sales
# Out:
# /var/folders/5z/3yrmkztd53d2q3tfg21lyc1r0000gn/T/ipykernel_30231/553388825.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$,\.\,]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Data"] = pd.date_range("1/1/2020",periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Data
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Data  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Data",y = "Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y = "Price",kind = "scatter");

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.97605996, 0.50117498, 0.86070963, 0.83978115],
#        [0.36686588, 0.50876218, 0.3618764 , 0.13760713],
#        [0.37072334, 0.98671212, 0.13730034, 0.83480794],
#        [0.1414994 , 0.25007892, 0.37303318, 0.64209426],
#        [0.58892138, 0.91573115, 0.11783556, 0.95674558],
#        [0.34821551, 0.39936165, 0.91634752, 0.16637078],
#        [0.25561098, 0.4899077 , 0.84655095, 0.16456934],
#        [0.42839655, 0.45073143, 0.76859971, 0.58757988],
#        [0.77171256, 0.40027745, 0.67758615, 0.49626138],
#        [0.58166041, 0.81328924, 0.30428106, 0.71984619]])

# %%
df = pd.DataFrame(x,columns =['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.976060  0.501175  0.860710  0.839781
# 1  0.366866  0.508762  0.361876  0.137607
# 2  0.370723  0.986712  0.137300  0.834808
# 3  0.141499  0.250079  0.373033  0.642094
# 4  0.588921  0.915731  0.117836  0.956746
# 5  0.348216  0.399362  0.916348  0.166371
# 6  0.255611  0.489908  0.846551  0.164569
# 7  0.428397  0.450731  0.768600  0.587580
# 8  0.771713  0.400277  0.677586  0.496261
# 9  0.581660  0.813289  0.304281  0.719846

# %%
df.plot.bar();

# %%
#alternative
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Data  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar")
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.plot.hist(figsize=(8,30),subplots=True);

# %%
over_50=heart_disease[heart_disease["age"]>50]
#len(over_50)
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
over_50.plot(kind="scatter",x="age",y="chol",c="target")
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
fig, ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax = ax)
#ax.set_xlim([40,100])
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
fig, ax=plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax.set(title="Heart diesease",xlabel="Age",ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(),title="Target")
ax.axhline(over_50["thalach"].mean(),linestyle="--");

# %%
fig, (ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])
ax0.set(title="Heart diesease",ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle="--");

scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"])
ax1.set(title="Heart diesease",xlabel="Age",ylabel="Thalach")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle="--")
fig.suptitle("Heart Disease Anal",fontsize=16,fontweight="bold");

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn-darkgrid")

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("seaborn-darkgrid")
fig, (ax0,ax1)=plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"],cmap="inferno")
ax0.set(title="Heart diesease",ylabel="Cholestrol")
ax0.set_xlim([50,80])
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle="--");

scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"],cmap="viridis")
ax1.set(title="Heart diesease",xlabel="Age",ylabel="Thalach")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle="--")
fig.suptitle("Heart Disease Anal",fontsize=16,fontweight="bold");
